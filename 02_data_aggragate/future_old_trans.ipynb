# %% [markdown]
# ![QuantConnect Logo](https://cdn.quantconnect.com/web/i/icon.png)
# <hr>

# %%
from AlgorithmImports import *
# Quick end-to-end test for V-bar footprint aggregation and storage
from datetime import date
import pandas as pd


qb = QuantBook()
symbol = qb.add_future(Futures.Indices.NASDAQ_100_E_MINI, Resolution.SECOND).symbol

start = date(2024, 1, 3)
end = date(2024, 1, 4)


print("Done.")


second_bars = qb.history(symbol, start, end, Resolution.SECOND,
                    extended_market_hours=True,
                    data_mapping_mode=DataMappingMode.OPEN_INTEREST_ANNUAL, 
                    data_normalization_mode=DataNormalizationMode.RAW, 
                    fill_forward=True
                    )

print(second_bars.head())

minute_bars = qb.history(symbol, start, end, Resolution.MINUTE,
                    extended_market_hours=True,
                    data_mapping_mode=DataMappingMode.OPEN_INTEREST_ANNUAL, 
                    data_normalization_mode=DataNormalizationMode.RAW, 
                    fill_forward=True
                    )


print(minute_bars.head())
# Out:
# Done.
#                                        askclose  askhigh  asklow  askopen  \
# expiry     symbol time
# 1899-12-30 /ES    2024-01-03 00:00:01    4783.5   4783.5  4783.5   4783.5
#                   2024-01-03 00:00:02    4783.5   4783.5  4783.5   4783.5
#                   2024-01-03 00:00:03    4783.5   4783.5  4783.5   4783.5
#                   2024-01-03 00:00:04    4783.5   4783.5  4783.5   4783.5
#                   2024-01-03 00:00:05    4783.5   4783.5  4783.5   4783.5
#
#                                        asksize  bidclose  bidhigh   bidlow  \
# expiry     symbol time
# 1899-12-30 /ES    2024-01-03 00:00:01     41.0   4783.25  4783.25  4783.25
#                   2024-01-03 00:00:02     49.0   4783.25  4783.25  4783.25
#                   2024-01-03 00:00:03     49.0   4783.25  4783.25  4783.25
#                   2024-01-03 00:00:04     41.0   4783.25  4783.25  4783.25
#                   2024-01-03 00:00:05     41.0   4783.25  4783.25  4783.25
#
#                                        bidopen  bidsize     close      high  \
# expiry     symbol time
# 1899-12-30 /ES    2024-01-03 00:00:01  4783.25     64.0  4783.375  4783.375
#                   2024-01-03 00:00:02  4783.25     62.0  4783.375  4783.375
#                   2024-01-03 00:00:03  4783.25     62.0  4783.375  4783.375
#                   2024-01-03 00:00:04  4783.25     62.0  4783.375  4783.375
#                   2024-01-03 00:00:05  4783.25     62.0  4783.375  4783.375
#
#                                             low      open  volume
# expiry     symbol time
# 1899-12-30 /ES    2024-01-03 00:00:01  4783.375  4783.375     NaN
#                   2024-01-03 00:00:02  4783.375  4783.375     NaN
#                   2024-01-03 00:00:03  4783.375  4783.375     NaN
#                   2024-01-03 00:00:04  4783.375  4783.375     NaN
#                   2024-01-03 00:00:05  4783.375  4783.375     NaN
# Empty DataFrame
# Columns: []
# Index: []
